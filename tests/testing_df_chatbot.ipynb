# %%
import pandas as pd
from pathlib import Path

# Xác định đường dẫn tới file parquet
parquet_path = Path("../src/rag/data/clean_guardian_articles.parquet")

# Đọc file parquet
df = pd.read_parquet(parquet_path)

# Xem tổng quan
print(f"✅ Loaded {len(df)} rows and {len(df.columns)} columns.")
df.head(3)
# Out:
# ✅ Loaded 9837 rows and 8 columns.
#                                           article_id  \
# 0  sport/live/2025/oct/26/new-zealand-v-england-f...
# 1  sport/live/2025/oct/26/england-v-new-zealand-w...
# 2  money/2025/oct/26/crash-for-cash-insurance-fra...
#
#                                                title  \
# 0      New Zealand v England: first men’s ODI – live
# 1  England v New Zealand: Women’s Cricket World C...
# 2  ‘Crash for cash’: moped riders target your ins...
#
#                                             headline  \
# 0      New Zealand v England: first men’s ODI – live
# 1  England v New Zealand: Women’s Cricket World C...
# 2  ‘Crash for cash’: moped riders target your ins...
#
#                                              summary  \
# 0  Over-by-over report: Join our writers for upda...
# 1  Over-by-over report: Join our writers for upda...
# 2  Fraudulent insurance policies are being taken ...
#
#                                              content  \
# 0  7.15am GMT 33rd over: New Zealand 191-5 (Mitch...
# 1  7.13am GMT 26th over: New Zealand 118-4 (Devin...
# 2  You are sitting in the car at a junction waiti...
#
#                published_at section  \
# 0 2025-10-26 07:15:52+00:00   Sport
# 1 2025-10-26 07:13:24+00:00   Sport
# 2 2025-10-26 07:00:56+00:00   Money
#
#                                              authors
# 0  simon burnton and rob smyth (earlier), taha ha...
# 1       tanya aldred (now) and james wallace (later)
# 2                                       shane hickey
